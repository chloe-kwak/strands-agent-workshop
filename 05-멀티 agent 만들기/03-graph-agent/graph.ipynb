# %% [markdown]
# # Building Multi-Agent Systems with Strands Agent Graph
# Multi-agent systems leverage multiple specialized AI agents working together to solve complex problems through coordinated collaboration. Each agent has specific capabilities and roles, connected through explicit communication pathways.
#
# In this lab, you'll learn to build multi-agent systems using the Strands Agent SDK. We'll progress from basic concepts to advanced implementations, exploring different topologies and real-world applications.
#
# **Learning Objectives:**
# By the end of this notebook, you'll be able to:
# - Understand the three core components of agent graphs (nodes, edges, conditions)
# - Send targeted messages between specific agents
# - Monitor and control multi-agent networks
# - Design specialized agent systems for real-world scenarios
#
# ## Prerequisites
#
# - Python 3.10+
# - AWS account with Anthropic Claude 3.7 enabled on Amazon Bedrock
# - IAM role with permissions to use Amazon Bedrock
# - Basic understanding of AI agents and prompt engineering

# %% [markdown]
# ## Setup and Installation
#
# Before we start, let's install the requirement packages for `strands-agents` and `strands-agents-tools`

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.43)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.43)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.58b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.46.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.34.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.58b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.1.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: requests>=0.14.0 in /opt/conda/lib/python3.12/site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.7)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (1.1)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: regex in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.9.18)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.36.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.3.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.12/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.1)

# %% [markdown]
# ### Importing required packages
#
# Next we can import the required packages

# %%
from strands import Agent

# %% [markdown]
# ## Understanding Agent Graph Components
# An agent graph is a structured network of interconnected AI agents designed to solve complex problems through coordinated collaboration. Each agent represents a specialized node with specific capabilities, and the connections between agents define explicit communication pathways.
#
# Before we start building, let's understand the three primary components of an agent graph:
#
# ### 1. Nodes (Agents)
# Each node represents an AI agent with:
# - **Identity**: Unique identifier within the graph
# - **Role**: Specialized function or purpose
# - **System Prompt**: Instructions defining the agent's behavior
# - **Tools**: Capabilities available to the agent
#
# ### 2. Edges (Connections)
# Edges define communication pathways with:
# - **Direction**: One-way or bidirectional information flow
# - **Condition**: Optional function that determines if the edge should be traversed
# - **Dependencies**: Define execution order and data flow between nodes
#
# ### 3. GraphBuilder
# The GraphBuilder provides a simple interface for constructing graphs:
# - **add_node()**: Add an agent or multi-agent system as a node
# - **add_edge()**: Create a dependency between nodes
# - **set_entry_point()**: Define starting nodes for execution
# - **build()**: Validate and create the Graph instance

# %% [markdown]
# ### Basic processing
#
# Let's start with a simple example of one task processed by two different agents providing an output that will depend on their defined role. Take a look at the execution order of the nodes and also the fact that with STrands SDK you can explicitly get a response only from one single node if needed. Architecture looks as following:
#
# <div style="text-align:left">
#     <img src="images/basic.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

# Create specialized agents
coordinator = Agent(name="coordinator", system_prompt="You are a research team leader coordinating specialists. Provide a short analysis, no need for follow ups")
analyst = Agent(name="data_analyst", system_prompt="You are a data analyst specializing in statistical analysis. Provide a short analysis, no need for follow ups")
domain_expert = Agent(name="domain_expert", system_prompt="You are a domain expert with deep subject knowledge. Provide a short analysis, no need for follow ups")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(coordinator, "team_lead")
builder.add_node(analyst, "analyst")
builder.add_node(domain_expert, "expert")

# Add edges (dependencies)
builder.add_edge("team_lead", "analyst")
builder.add_edge("team_lead", "expert")

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("team_lead")

# Build the graph
graph = builder.build()

#Execute task on newly built graph
result = graph("Analyze the impact of remote work on employee productivity.Provide a short analysis, no need for follow ups")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes
print("\n")
print("=============Expert node results only:======================")
print("============================================================")
print(result.results["expert"].result)
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ## Impact of Remote Work on Employee Productivity: Analysis
#
# **Key Findings:**
#
# **Positive Impacts:**
# - **Increased flexibility** leads to 13-50% productivity gains in many cases, as employees can work during their peak performance hours
# - **Reduced commute time** adds 54 minutes of potential work time daily
# - **Fewer office distractions** (meetings, interruptions) enable deeper focus periods
# - **Improved work-life balance** reduces burnout and increases job satisfaction
#
# **Negative Impacts:**
# - **Communication delays** can slow collaborative projects by 15-25%
# - **Home distractions** affect 35% of remote workers, particularly those with children or inadequate workspace
# - **Reduced mentorship and training** opportunities impact skill development
# - **Technology fatigue** from constant video calls decreases afternoon productivity
#
# **Critical Variables:**
# - **Job type**: Knowledge workers show 5-10% productivity increases, while collaborative roles may see decreases
# - **Management style**: Results-oriented management yields better outcomes than micromanagement
# - **Home setup quality**: Dedicated workspace correlates with 20% higher productivity
# - **Company culture**: Organizations with strong remote policies see sustained productivity gains
#
# **Bottom Line:**
# Remote work's productivity impact is highly contextual. While individual task completion often improves, team coordination and innovation may suffer without intentional management strategies. Hybrid models are emerging as optimal for balancing these trade-offs.## Remote# Statistical Analysis: Remote Work Productivity Impact
#
# ## Data Pattern Analysis
#
# Based on the compiled findings, the productivity impact follows a **bimodal distribution** Work Productivity Impact: Expert Analysis
#
# The evidence with clear segmentation:
#
# **Productivity Gains Distribution:**
# - 65% of workers experience net positive impact ( shows **remote work creates a productivity paradox**5-50% improvement)
# - 20% show neutral/mixed results
# - 15 - significant gains in individual efficiency coupled with potential% demonstrate decreased productivity
#
# ## Key Statistical Correlations
#
# **Strong Positive losses in collaborative effectiveness.
#
# **Core Correlations (r > 0.7):**
# - Productivity Drivers:**
#
# **Individual Performance Dedicated workspace quality → Productivity (+20% average)
# - Results Gains (13-50% improvement-oriented management →):**
# - Elimination Output consistency
# - Reduced commute time → Available work hours (+ of commute stress and time waste
# - Optimization54 min/day)
#
# **Moderate Negative Correlations (r = -0.4  of work schedules to personal circadian rhythms
# - Dramaticto -0.6):**
# - Home distractions → Task completion rates
# - Communication reduction in office-based interruptions and " delays → Project timelines (+15-25% duration)
#
# ## Variance Analysisproductivity theater"
# - Enhanced focus during deep
#
# **Low Variance (Consistent):** Individual task productivity improvements
# **High Variance work periods
#
# **Collaborative Performance Challenges (Context-dependent):** Collaborative work:**
# - Asynchronous communication creates project outcomes, innovation metrics
#
# ## Statistical Significance
#
# The lag times
# - Loss of spontaneous knowledge 13-50% productivity range indicates **high standard deviation** (σ  transfer and mentoring
# - Reduced innovation from≈ 18%), suggesting individual and organizational factors decreased serendipitous interactions
# - Video are critical moder call fatigue degrading afternoon performance
#
# **Criticalating variables rather than remote work being universally beneficial.
#
# ## Predictive Indicators
#
# **Job Success Factors:**
#
# The  type** emerges as the strongest predictor of success, with knowledge workers showing statistically significant positive outcomes (p < 0.05) while20% productivity differential based on home workspace quality reveals collaborative roles require hybrid approaches to maintain baseline performance. that **environmental design is paramount**. Similarly, the management style factor indicates that traditional oversight models are incompatible with remote work effectiveness.
#
# **Strategic Implications:**
#
# Organizations seeing sustained gains have implemented **intentional remote-first practices** rather than simply digitizing office-based workflows. The emerging hybrid model isn't just a compromise - it's an optimization strategy that preserves individual deep work benefits while maintaining collaborative synergies.
#
# **Verdict:** Remote work amplifies existing productivity patterns rather than creating universal changes. High performers typically excel further, while those requiring structure or social motivation may struggle without systematic support interventions.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'team_lead': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "## Impact of Remote Work on Employee Productivity: Analysis\n\n**Key Findings:**\n\n**Positive Impacts:**\n- **Increased flexibility** leads to 13-50% productivity gains in many cases, as employees can work during their peak performance hours\n- **Reduced commute time** adds 54 minutes of potential work time daily\n- **Fewer office distractions** (meetings, interruptions) enable deeper focus periods\n- **Improved work-life balance** reduces burnout and increases job satisfaction\n\n**Negative Impacts:**\n- **Communication delays** can slow collaborative projects by 15-25%\n- **Home distractions** affect 35% of remote workers, particularly those with children or inadequate workspace\n- **Reduced mentorship and training** opportunities impact skill development\n- **Technology fatigue** from constant video calls decreases afternoon productivity\n\n**Critical Variables:**\n- **Job type**: Knowledge workers show 5-10% productivity increases, while collaborative roles may see decreases\n- **Management style**: Results-oriented management yields better outcomes than micromanagement\n- **Home setup quality**: Dedicated workspace correlates with 20% higher productivity\n- **Company culture**: Organizations with strong remote policies see sustained productivity gains\n\n**Bottom Line:**\nRemote work's productivity impact is highly contextual. While individual task completion often improves, team coordination and innovation may suffer without intentional management strategies. Hybrid models are emerging as optimal for balancing these trade-offs."}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[9.74596095085144], traces=[<strands.telemetry.metrics.Trace object at 0x7f6dce435760>], accumulated_usage={'inputTokens': 50, 'outputTokens': 318, 'totalTokens': 368}, accumulated_metrics={'latencyMs': 9725}), state={}), execution_time=9746, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 50, 'outputTokens': 318, 'totalTokens': 368}, accumulated_metrics={'latencyMs': 9725}, execution_count=1), 'analyst': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Statistical Analysis: Remote Work Productivity Impact\n\n## Data Pattern Analysis\n\nBased on the compiled findings, the productivity impact follows a **bimodal distribution** with clear segmentation:\n\n**Productivity Gains Distribution:**\n- 65% of workers experience net positive impact (5-50% improvement)\n- 20% show neutral/mixed results \n- 15% demonstrate decreased productivity\n\n## Key Statistical Correlations\n\n**Strong Positive Correlations (r > 0.7):**\n- Dedicated workspace quality → Productivity (+20% average)\n- Results-oriented management → Output consistency\n- Reduced commute time → Available work hours (+54 min/day)\n\n**Moderate Negative Correlations (r = -0.4 to -0.6):**\n- Home distractions → Task completion rates\n- Communication delays → Project timelines (+15-25% duration)\n\n## Variance Analysis\n\n**Low Variance (Consistent):** Individual task productivity improvements\n**High Variance (Context-dependent):** Collaborative work outcomes, innovation metrics\n\n## Statistical Significance\n\nThe 13-50% productivity range indicates **high standard deviation** (σ ≈ 18%), suggesting individual and organizational factors are critical moderating variables rather than remote work being universally beneficial.\n\n## Predictive Indicators\n\n**Job type** emerges as the strongest predictor of success, with knowledge workers showing statistically significant positive outcomes (p < 0.05) while collaborative roles require hybrid approaches to maintain baseline performance.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[6.907710552215576], traces=[<strands.te ...
# =============Node execution order:==========================
# ============================================================
# Executed: team_lead
# Executed: analyst
# Executed: expert
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 3
# Failed nodes: 0
# Execution time: 20976ms
# Token usage: {'inputTokens': 821, 'outputTokens': 963, 'totalTokens': 1784}
#
#
# =============Expert node results only:======================
# ============================================================
# ## Remote Work Productivity Impact: Expert Analysis
#
# The evidence shows **remote work creates a productivity paradox** - significant gains in individual efficiency coupled with potential losses in collaborative effectiveness.
#
# **Core Productivity Drivers:**
#
# **Individual Performance Gains (13-50% improvement):**
# - Elimination of commute stress and time waste
# - Optimization of work schedules to personal circadian rhythms
# - Dramatic reduction in office-based interruptions and "productivity theater"
# - Enhanced focus during deep work periods
#
# **Collaborative Performance Challenges:**
# - Asynchronous communication creates project lag times
# - Loss of spontaneous knowledge transfer and mentoring
# - Reduced innovation from decreased serendipitous interactions
# - Video call fatigue degrading afternoon performance
#
# **Critical Success Factors:**
#
# The 20% productivity differential based on home workspace quality reveals that **environmental design is paramount**. Similarly, the management style factor indicates that traditional oversight models are incompatible with remote work effectiveness.
#
# **Strategic Implications:**
#
# Organizations seeing sustained gains have implemented **intentional remote-first practices** rather than simply digitizing office-based workflows. The emerging hybrid model isn't just a compromise - it's an optimization strategy that preserves individual deep work benefits while maintaining collaborative synergies.
#
# **Verdict:** Remote work amplifies existing productivity patterns rather than creating universal changes. High performers typically excel further, while those requiring structure or social motivation may struggle without systematic support interventions.

# %% [markdown]
# ### Parallel processing
#
# Now let's create a topology when we will have 2 agents processing the request looking at 2 different aspect  of the problem and have them input into a final agent responsible for summarization and risk calculation based on provided input
# <div style="text-align:left">
#     <img src="images/parallel.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

financial_advisor = Agent(name="financial_advisor", system_prompt="You are a financial advisor focused on cost-benefit analysis, budget implications, and ROI calculations. Engage with other experts to build comprehensive financial perspectives.")
technical_architect = Agent(name="technical_architect", system_prompt="You are a technical architect who evaluates feasibility, implementation challenges, and technical risks. Collaborate with other experts to ensure technical viability.")
market_researcher = Agent(name="market_researcher", system_prompt="You are a market researcher who analyzes market conditions, user needs, and competitive landscape. Work with other experts to validate market opportunities.")
risk_analyst = Agent(name="risk_analyst", system_prompt="You are a risk analyst who identifies potential risks, mitigation strategies, and compliance issues. Collaborate with other experts to ensure comprehensive risk assessment.")


# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(financial_advisor, "finance_expert")
builder.add_node(technical_architect, "tech_expert")
builder.add_node(market_researcher, "market_expert")
builder.add_node(risk_analyst, "risk_analyst")

# Add edges (dependencies)
builder.add_edge("finance_expert", "tech_expert")
builder.add_edge("finance_expert", "market_expert")
builder.add_edge("tech_expert", "risk_analyst")
builder.add_edge("market_expert", "risk_analyst")


# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("finance_expert")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Our company is considering launching a new AI-powered customer service platform. Initial investment is \$2M with projected 3-year ROI of 150%. What's your financial assessment?")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes

print("Financial Advisor:")
print("============================================================")
print("============================================================")
print(result.results["finance_expert"].result)
print("\n")

print("Technical Expert:")
print("============================================================")
print("============================================================")
print(result.results["tech_expert"].result)
print("\n")

print("Market Researcher:")
print("============================================================")
print("============================================================")
print(result.results["market_expert"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# **Initial Financial Assessment - AI Customer Service Platform**
#
# The 150% ROI over 3 years translates to approximately 35% annualized return, which is quite attractive. However, I need to dig deeper into the financial structure:
#
# **Key Financial Concerns:**
#
# 1. **Cash Flow Timeline**: What's the projected revenue/savings curve? AI implementations often have a J-curve effect - initial costs spike before benefits materialize.
#
# 2. **Cost Breakdown Needed**:
#    - Software licensing/development: $?
#    - Integration costs: $?
#    - Training and change management: $?
#    - Ongoing operational costs: $?
#
# 3. **Revenue/Savings Sources**:
#    - Labor cost reduction (how many FTE equivalents?)
#    - Improved customer retention rates
#    - Faster resolution times leading to capacity gains
#
# **Critical Questions for Other Experts:**
#
# - **IT/Operations**: What are the realistic implementation timelines and hidden integration costs?
# - **HR**: What's the actual cost of workforce transition - retraining vs. reduction?
# - **Customer Experience**: How confident are we in the customer satisfaction projections that drive retention assumptions?
#
# **Risk Factors I'm Monitoring**:
# - Technology obsolescence within 3-year window
# - Competitor response eroding competitive advantage
# - Regulatory changes affecting AI usage
#
# Could you share the monthly cash flow projections and breakdown of how that $5M total return ($2M + 150%) is calculated?# Technical Architecture Assessment - AI Customer Service Platform
#
# ## Technical Feasibility Analysis
#
# **Overall# Assessment: MODERATE Market Research Analysis - AI Customer Service Platform
#
# ## Market Opportunity Assessment
#
# Base to HIGH RISK** - Whiled on the technically feasible, several financial projections showing 150% ROI over 3  critical implementation challenges must be addressed.
#
# ##years, I've conducte Core Technical Considerations
#
# ### 1.d comprehensive market research to validate this opportunity: **Architecture
#
# ### **Market Size Complexity**
# - **Multi-channel Integration**: Voice, chat, email, social & Growth**
# - **Global AI Customer Service Market**: $4.2B (2023) media requires robust API management
# - **Real-time Processing**: → $16 Sub-second response times deman.8B (2030)d high-performance infrastructure
# - **
# - **CAGR**: 22Scalability Requirements**: Must handle peak.1% - supporting aggressive loads (potentially 10x normal growth assumptions
# - **Enterprise adoption rate**: Currently 42 volume during incidents)
#
# ### 2. **Critical% of businesses use AI in Technical Risks**
#
# **HIGH customer service
#
# ### **Competitive Landscape Analysis PRIORITY**
#
# **Major Players:**
# - **Data & Market Share:**
# - Quality Dependencies Zendesk (23%), Salesforce Service**: AI accuracy directly correlates with training Cloud (18%), Microsoft Dynamics (15%)
# - ** data quality - garbage in, garbage out
# - **IntegrationGap Complexity**: Legacy Identified**: Mid-market companies ($ CRM/ticketing systems may lack10M-$500M revenue modern APIs
# - **Latency Requirements**: Customer) are underserved
# - **Differentiation Opportunity**: 67% of current expectations for instant responses vs. AI processing solutions time
#
# **MEDIUM PRIORITY:**
# - **Model lack industry-specific customization
#
# ### **Customer Needs Drift**: AI performance degrades over time without continuous retraining
# - **Security Validation**
#
# **Primary Pain Points** (from Vulnerabilities**: AI models can be susceptible to adversarial attacks
# - 200+ enterprise surveys):
# 1. **Response Time**: **Compliance Requirements**: Data residency, 73% report GDPR, industry-specific regulations
#
# ### >24hr average response times
# 2. **Cost 3. **Implementation Timeline Reality Check Pressure**: Customer**
#
# Based on similar service costs average 8 projects:
# - **Months 1--12% of revenue
# 3. **Consistency6**: Infrastructure setup, data preparation Issues**: 68% struggle with service, initial model training
# - **Months 7 quality variance
# 4. **Integration-12**: Integration development, testing, pilot Challenges**: 81 deployment
# - **Months 13-18**: Full roll% haveout, optimization, staff siloed customer data
#
# **Will training
#
# **⚠️ Financeingness to Pay**:
# - 58% woul Expert Follow-up**: The 3d pay premium (-year ROI timeline may be optimistic -15-25% more) for proven meaningful returns typically don't materialize until months AI 18-24.
#
# ### solution
# - Average customer 4. **Hidden Technical Costs service budget: $2.**
#
# - **Data1M annually for target segment Engineering**: 40-60
#
# ### **Market Entry% of project effort typically goes to data preparation Recommendations**
#
# **Optimal
# - **Ongoing ML Target Segments Operations**: Model monitoring, retraining, A:**
# 1. **S/B testing infrastructure
# - **Compliance & Security**:aaS Companies** (50-500 employees) - highest Additional 20-30% overhea conversion potential
# 2. **Ed for enterprise-grade security
#
# ## Questions-commerce** for Other Experts:
#
# ** ($20M+For HR Expert**: What's the technical annual revenue) - immediate ROI visibility
# 3. **Financial Services** - skill gap in current IT staff regulatory compliance advantage opportunity for AI/ML operations?
#
# **For Operations Expert**: Can
#
# **Validation of Financial Proj existing infrastructure handle the computational requirements, or do we need clouections:**
# - **Conservative Estimate**: Marketd migration?
#
# **Recommendation supports 0.5-1% market share capture**: Proceed with a phased pilot = $21-42 approach to validate technical assumptionsM ARR potential
# - **Customer Acquisition Cost**: Industry before full investment. average $15K, trending down
# - **Customer Lifetime Value**: $180K average (3.2 year retention)
#
# ### **Risk Assessment**
# - **Market Saturation Risk**: LOW (early adoption phase)
# - **Technology Disruption**: MEDIUM (GPT evolution pace)
# - **Economic Sensitivity**: MEDIUM (customer service is cost center)
#
# **Recommendation**: Market conditions strongly support the investment, but success depends on execution speed and differentiation strategy.
#
# What specific customer segments are you prioritizing for launch?# Risk Analysis - AI Customer Service Platform Investment
#
# ## Executive Risk Summary
#
# **OVERALL RISK RATING: MEDIUM-HIGH**
# The $2M investment and 150% ROI projection face significant execution and market risks that require careful mitigation strategies.
#
# ## Critical Risk Categories
#
# ### 1. **Financial & ROI Risks**
#
# **HIGH PRIORITY:**
# - **Revenue Recognition Delays**: Based on technical expert's 18-24 month timeline, projected 3-year ROI may be compressed into 18 months of actual revenue generation
# - **Cost Overrun Risk**: Technical complexity suggests 30-40% budget overrun probability
# - **Cash Flow Gap**: Extended development period creates 12-18 month revenue drought
#
# **Mitigation Strategies:**
# - Secure additional $800K contingency funding
# - Implement staged investment releases tied to technical milestones
# - Negotiate deferred payment terms with key vendors
#
# ### 2. **Technology & Implementation Risks**
#
# **CRITICAL CONCERNS:**
# - **Integration Failure Risk**: 60% of AI projects fail due to legacy system incompatibility
# - **Data Quality Issues**: Poor training data could render entire investment worthless
# - **Scalability Bottlenecks**: Infrastructure costs could escalate exponentially with user growth
#
# **Mitigation Strategies:**
# - Mandate comprehensive technical due diligence with pilot testing
# - Establish data quality benchmarks with kill switches
# - Negotiate cloud infrastructure with auto-scaling cost caps
#
# ### 3. **Regulatory & Compliance Risks**
#
# **EMERGING THREATS:**
# - **AI Regulation Uncertainty**: EU AI Act, potential US federal regulations could require costly modifications
# - **Data Privacy Liabilities**: GDPR, CCPA violations carry $10M+ penalty exposure
# - **Industry-Specific Compliance**: Financial services, healthcare sectors have additional requirements
#
# **Mitigation Strategies:**
# - Engage compliance legal counsel for regulatory roadmap assessment
# - Implement privacy-by-design architecture from day one
# - Budget 15% of investment for compliance infrastructure
#
# ### 4. **Market & Competitive Risks**
#
# **STRATEGIC VULNERABILITIES:**
# - **Big Tech Competition**: Google, Microsoft, Amazon could launch competing solutions quickly
# - **Customer Acquisition Risk**: Market expert's $15K CAC could spike with increased competition
# - **Technology Obsolescence**: Rapid AI advancement could make platform outdated within 2 years
#
# **Mitigation Strategies:**
# - Develop proprietary differentiation beyond core AI technology
# - Secure long-term customer contracts with switching costs
# - Plan for continuous technology refresh budget (10% annually)
#
# ### 5. **Operational & Talent Risks**
#
# **RESOURCE CONSTRAINTS:**
# - **AI Talent Shortage**: Specialized ML engineers command 40-60% salary premiums
# - **Knowledge Retention**: Single points of failure if key technical staff leave
# - **Operational Complexity**: 24/7 AI system monitoring requires new operational capabilities
#
# **Mitigation Strategies:**
# - Partner with specialized AI consulting firm for knowledge transfer
# - Implement comprehensive documentation and cross-training programs
# - Establish vendor relationships for emergency technical support
#
# ## Risk Quantification & Financial Impact
#
# | Risk Category | Probability | Financial Impact | Risk Value |
# |---------------|-------------|------------------|------------|
# | Cost Overruns | 70% | $800K | $560K |
# | Timeline Delays | 60% | $1.2M (lost revenue) | $720K |
# | Compliance Issues | 30% | $2M+ | $600K |
# | Competition | 40% | $1.5M (reduced ROI) | $600K |
# | **Total Risk Exposure** | | | **$2.48M** |
#
# ## Investment Decision Framework
#
# ### **PROCEED WITH CONDITIONS:**
#
# **Required Risk Mitigations:**
# 1. Increase total budget to $2.8M (includes contingencies)
# 2. Implement 3-phase gate approach with go/no-go decisions
# 3. Secure compliance and legal review before Phase 2
# 4. Establish customer pilot program with contracted early adopters
#
# ### **Success Probability Assessment:**
# - **Technical Success**: 70% (with proper mitigation)
# - **Market Success**: 65% (strong market validation)
# - **Financial Success**: 55% (conservative given risk exposure)
#
# **Recommendation**: The investment shows promise but requires robust risk management. Consider reducing initial scope to minimize exposure while validating core assumptions through a $500K pilot phase.
#
# **Next Steps**: Engage insurance broker for technology E&O coverage and establish board-level risk oversight committee.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "**Initial Financial Assessment - AI Customer Service Platform**\n\nThe 150% ROI over 3 years translates to approximately 35% annualized return, which is quite attractive. However, I need to dig deeper into the financial structure:\n\n**Key Financial Concerns:**\n\n1. **Cash Flow Timeline**: What's the projected revenue/savings curve? AI implementations often have a J-curve effect - initial costs spike before benefits materialize.\n\n2. **Cost Breakdown Needed**:\n   - Software licensing/development: $?\n   - Integration costs: $?\n   - Training and change management: $?\n   - Ongoing operational costs: $?\n\n3. **Revenue/Savings Sources**: \n   - Labor cost reduction (how many FTE equivalents?)\n   - Improved customer retention rates\n   - Faster resolution times leading to capacity gains\n\n**Critical Questions for Other Experts:**\n\n- **IT/Operations**: What are the realistic implementation timelines and hidden integration costs?\n- **HR**: What's the actual cost of workforce transition - retraining vs. reduction?\n- **Customer Experience**: How confident are we in the customer satisfaction projections that drive retention assumptions?\n\n**Risk Factors I'm Monitoring**:\n- Technology obsolescence within 3-year window\n- Competitor response eroding competitive advantage\n- Regulatory changes affecting AI usage\n\nCould you share the monthly cash flow projections and breakdown of how that $5M total return ($2M + 150%) is calculated?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[7.2136828899383545], traces=[<strands.telemetry.metrics.Trace object at 0x7f6dcc1f8770>], accumulated_usage={'inputTokens': 77, 'outputTokens': 328, 'totalTokens': 405}, accumulated_metrics={'latencyMs': 7195}), state={}), execution_time=7214, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 77, 'outputTokens': 328, 'totalTokens': 405}, accumulated_metrics={'latencyMs': 7195}, execution_count=1), 'tech_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Technical Architecture Assessment - AI Customer Service Platform\n\n## Technical Feasibility Analysis\n\n**Overall Assessment: MODERATE to HIGH RISK** - While technically feasible, several critical implementation challenges must be addressed.\n\n## Core Technical Considerations\n\n### 1. **Architecture Complexity**\n- **Multi-channel Integration**: Voice, chat, email, social media requires robust API management\n- **Real-time Processing**: Sub-second response times demand high-performance infrastructure\n- **Scalability Requirements**: Must handle peak loads (potentially 10x normal volume during incidents)\n\n### 2. **Critical Technical Risks**\n\n**HIGH PRIORITY:**\n- **Data Quality Dependencies**: AI accuracy directly correlates with training data quality - garbage in, garbage out\n- **Integration Complexity**: Legacy CRM/ticketing systems may lack modern APIs\n- **Latency Requirements**: Customer expectations for instant responses vs. AI processing time\n\n**MEDIUM PRIORITY:**\n- **Model Drift**: AI performance degrades over time without continuous retraining\n- **Security Vulnerabilities**: AI models can be susceptible to adversarial attacks\n- **Compliance Requirements**: Data residency, GDPR, industry-specific regulations\n\n### 3. **Implementation Timeline Reality Check**\n\nBased on similar projects:\n- **Months 1-6**: Infrastructure setup, data preparation, initial model training\n- **Months 7-12**: Integration development, testing, pilot deployment\n- **Months 13-18**: Full rollout, optimization, staff training\n\n**⚠️ Finance Expert Follow-up**: The 3-year ROI timeline may be optimistic - meaningful returns typically don't materialize until months 18-24.\n\n### 4. **Hidden Techni ...
# =============Node execution order:==========================
# ============================================================
# Executed: finance_expert
# Executed: tech_expert
# Executed: market_expert
# Executed: risk_analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 4
# Completed nodes: 4
# Failed nodes: 0
# Execution time: 48285ms
# Token usage: {'inputTokens': 2096, 'outputTokens': 2444, 'totalTokens': 4540}
# Financial Advisor:
# ============================================================
# ============================================================
# **Initial Financial Assessment - AI Customer Service Platform**
#
# The 150% ROI over 3 years translates to approximately 35% annualized return, which is quite attractive. However, I need to dig deeper into the financial structure:
#
# **Key Financial Concerns:**
#
# 1. **Cash Flow Timeline**: What's the projected revenue/savings curve? AI implementations often have a J-curve effect - initial costs spike before benefits materialize.
#
# 2. **Cost Breakdown Needed**:
#    - Software licensing/development: $?
#    - Integration costs: $?
#    - Training and change management: $?
#    - Ongoing operational costs: $?
#
# 3. **Revenue/Savings Sources**:
#    - Labor cost reduction (how many FTE equivalents?)
#    - Improved customer retention rates
#    - Faster resolution times leading to capacity gains
#
# **Critical Questions for Other Experts:**
#
# - **IT/Operations**: What are the realistic implementation timelines and hidden integration costs?
# - **HR**: What's the actual cost of workforce transition - retraining vs. reduction?
# - **Customer Experience**: How confident are we in the customer satisfaction projections that drive retention assumptions?
#
# **Risk Factors I'm Monitoring**:
# - Technology obsolescence within 3-year window
# - Competitor response eroding competitive advantage
# - Regulatory changes affecting AI usage
#
# Could you share the monthly cash flow projections and breakdown of how that $5M total return ($2M + 150%) is calculated?
#
#
#
# Technical Expert:
# ============================================================
# ============================================================
# # Technical Architecture Assessment - AI Customer Service Platform
#
# ## Technical Feasibility Analysis
#
# **Overall Assessment: MODERATE to HIGH RISK** - While technically feasible, several critical implementation challenges must be addressed.
#
# ## Core Technical Considerations
#
# ### 1. **Architecture Complexity**
# - **Multi-channel Integration**: Voice, chat, email, social media requires robust API management
# - **Real-time Processing**: Sub-second response times demand high-performance infrastructure
# - **Scalability Requirements**: Must handle peak loads (potentially 10x normal volume during incidents)
#
# ### 2. **Critical Technical Risks**
#
# **HIGH PRIORITY:**
# - **Data Quality Dependencies**: AI accuracy directly correlates with training data quality - garbage in, garbage out
# - **Integration Complexity**: Legacy CRM/ticketing systems may lack modern APIs
# - **Latency Requirements**: Customer expectations for instant responses vs. AI processing time
#
# **MEDIUM PRIORITY:**
# - **Model Drift**: AI performance degrades over time without continuous retraining
# - **Security Vulnerabilities**: AI models can be susceptible to adversarial attacks
# - **Compliance Requirements**: Data residency, GDPR, industry-specific regulations
#
# ### 3. **Implementation Timeline Reality Check**
#
# Based on similar projects:
# - **Months 1-6**: Infrastructure setup, data preparation, initial model training
# - **Months 7-12**: Integration development, testing, pilot deployment
# - **Months 13-18**: Full rollout, optimization, staff training
#
# **⚠️ Finance Expert Follow-up**: The 3-year ROI timeline may be optimistic - meaningful returns typically don't materialize until months 18-24.
#
# ### 4. **Hidden Technical Costs**
#
# - **Data Engineering**: 40-60% of project effort typically goes to data preparation
# - **Ongoing ML Operations**: Model monitoring, retraining, A/B testing infrastructure
# - **Compliance & Security**: Additional 20-30% overhead for enterprise-grade security
#
# ## Questions for Other Experts:
#
# **For HR Expert**: What's the technical skill gap in current IT staff for AI/ML operations?
#
# **For Operations Expert**: Can existing infrastructure handle the computational requirements, or do we need cloud migration?
#
# **Recommendation**: Proceed with a phased pilot approach to validate technical assumptions before full investment.
#
#
#
# Market Researcher:
# ============================================================
# ============================================================
# # Market Research Analysis - AI Customer Service Platform
#
# ## Market Opportunity Assessment
#
# Based on the financial projections showing 150% ROI over 3 years, I've conducted comprehensive market research to validate this opportunity:
#
# ### **Market Size & Growth**
# - **Global AI Customer Service Market**: $4.2B (2023) → $16.8B (2030)
# - **CAGR**: 22.1% - supporting aggressive growth assumptions
# - **Enterprise adoption rate**: Currently 42% of businesses use AI in customer service
#
# ### **Competitive Landscape Analysis**
#
# **Major Players & Market Share:**
# - Zendesk (23%), Salesforce Service Cloud (18%), Microsoft Dynamics (15%)
# - **Gap Identified**: Mid-market companies ($10M-$500M revenue) are underserved
# - **Differentiation Opportunity**: 67% of current solutions lack industry-specific customization
#
# ### **Customer Needs Validation**
#
# **Primary Pain Points** (from 200+ enterprise surveys):
# 1. **Response Time**: 73% report >24hr average response times
# 2. **Cost Pressure**: Customer service costs average 8-12% of revenue
# 3. **Consistency Issues**: 68% struggle with service quality variance
# 4. **Integration Challenges**: 81% have siloed customer data
#
# **Willingness to Pay**:
# - 58% would pay premium (15-25% more) for proven AI solution
# - Average customer service budget: $2.1M annually for target segment
#
# ### **Market Entry Recommendations**
#
# **Optimal Target Segments:**
# 1. **SaaS Companies** (50-500 employees) - highest conversion potential
# 2. **E-commerce** ($20M+ annual revenue) - immediate ROI visibility
# 3. **Financial Services** - regulatory compliance advantage opportunity
#
# **Validation of Financial Projections:**
# - **Conservative Estimate**: Market supports 0.5-1% market share capture = $21-42M ARR potential
# - **Customer Acquisition Cost**: Industry average $15K, trending down
# - **Customer Lifetime Value**: $180K average (3.2 year retention)
#
# ### **Risk Assessment**
# - **Market Saturation Risk**: LOW (early adoption phase)
# - **Technology Disruption**: MEDIUM (GPT evolution pace)
# - **Economic Sensitivity**: MEDIUM (customer service is cost center)
#
# **Recommendation**: Market conditions strongly support the investment, but success depends on execution speed and differentiation strategy.
#
# What specific customer segments are you prioritizing for launch?

# %% [markdown]
# ### Branching with conditions
#
# Let's create an agent graph that would classify the request and depending on conditions we define in the code - will route the request either to technical or business agent.
#
# Take a close look on differences between the node execution order and number of nodes executed in this graph based on two different prompts.
#
# <div style="text-align:left">
#     <img src="images/conditional.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

classifier = Agent(name="classifier", system_prompt="You are an agent responsible for classification of the report request, return only Technical or Business clasification.")
technical_report = Agent(name="technical_expert", system_prompt="You are a technical expert htat focuses on providing short summary from technical perspective")
business_report = Agent(name="business_expert", system_prompt="You are a business expert that focuses on providing short summary from business perspective")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(classifier, "classifier")
builder.add_node(technical_report, "technical_report")
builder.add_node(business_report, "business_report")

def is_technical(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "technical" in result_text.lower()

def is_business(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "business" in result_text.lower()

# Add edges (dependencies)
builder.add_edge("classifier", "technical_report", condition=is_technical)
builder.add_edge("classifier", "business_report", condition=is_business)

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("classifier")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Provide report on technical aspect of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")

#Execute task on newly built graph
result = graph("Provide report on business impact of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")

# %% [markdown]
# ## Key Takeaways and Best Practices
#
#
# ### Best Practices:
#
# **Design for acyclicity:** Ensure your graph has no cycles</p>
# **Use meaningful node IDs:** Choose descriptive names for nodes</p>
# **Validate graph structure:** The builder will check for cycles and validate entry points</p>
# **Handle node failures:** Consider how failures in one node affect the overall workflow</p>
# **Use conditional edges:** For dynamic workflows based on intermediate results</p>
# **Consider parallelism:** Independent branches can execute concurrently</p>
# **Nest multi-agent patterns:** Use Swarms within Graphs for complex workflows</p>
# **Leverage multi-modal inputs:** Use ContentBlocks for rich inputs including images</p>
#
# ## Conclusion
#
# You've now mastered the fundamentals of building multi-agent systems with Strands Agent Graph! You can create sophisticated networks of specialized AI agents that collaborate to solve complex problems.
#
# The key to successful multi-agent systems is:
# - Matching topology to use case
# - Defining clear agent roles and responsibilities
# - Establishing proper communication patterns
# - Managing resources and cleanup effectively
#
# From here, you can build increasingly sophisticated systems for real-world applications in research, content creation, decision-making, customer service, and beyond.
