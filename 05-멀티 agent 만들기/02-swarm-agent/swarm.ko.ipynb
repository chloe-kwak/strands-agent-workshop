# %% [markdown]
# # Strands Agents를 사용한 에이전트 스웜 생성

# %% [markdown]
# ## 스웜 멀티 에이전트 시스템 이해하기
#
# 스웜은 여러 에이전트가 팀으로 협력하여 복잡한 작업을 해결하는 협업 에이전트 오케스트레이션 시스템입니다. 전통적인 순차적 또는 계층적 멀티 에이전트 시스템과 달리, 스웜은 공유 컨텍스트와 작업 메모리를 가진 에이전트 간의 자율적 조정을 가능하게 합니다.
#
# * **공유 작업 메모리**를 가진 **자기 조직화 에이전트 팀**
# * 에이전트 간 **도구 기반 조정**
# * 중앙 제어 없는 **자율적 에이전트 협업**
# * 에이전트 능력에 기반한 **동적 작업 분배**
# * 공유 컨텍스트를 통한 **집단 지능**
# * 텍스트, 이미지 및 기타 콘텐츠 유형 처리를 위한 **멀티모달 입력 지원**
#
# ## 스웜 작동 방식
#
# 스웜은 창발적 지능의 원리로 작동합니다 - 전문화된 에이전트 그룹이 함께 작업하면 단일 에이전트보다 더 효과적으로 문제를 해결할 수 있다는 아이디어입니다. 스웜의 각 에이전트는:
#
# 1. 전체 작업 컨텍스트에 접근할 수 있습니다
# 2. 어떤 에이전트가 작업에 참여했는지 기록을 볼 수 있습니다
# 3. 다른 에이전트가 기여한 공유 지식에 접근할 수 있습니다
# 4. 다른 전문 지식을 가진 다른 에이전트에게 언제 넘겨줄지 결정할 수 있습니다

# %% [markdown]
# ## 1. 스웜 도구로 빠른 시작

# %% [markdown]
# Strands Agents SDK는 멀티 에이전트 시스템의 구현을 단순화하는 내장 스웜 도구를 제공하여 사용자에게 빠른 시작을 제공합니다. 이 도구는 전문화된 에이전트 간의 자율적 조정을 통한 유연한 스웜 지능 시스템을 구현합니다.
#
# 이 예시에서:
# 1. 에이전트는 스웜 도구를 사용하여 전문화된 에이전트 팀을 동적으로 생성합니다. 여기에는 연구원, 분석가, 기술 작성자가 포함될 수 있습니다
# 2. 다음으로 에이전트가 스웜을 실행합니다
# 3. 스웜 에이전트들이 자율적으로 협업하며 필요에 따라 서로에게 넘겨줍니다
# 4. 에이전트가 스웜 결과를 분석하고 사용자에게 포괄적인 응답을 제공합니다

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.1)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.38)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.12.4)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.58b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.7)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.11.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.26.19)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: httpx>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.47.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.35.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (6.10.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.58b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.1.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: requests>=0.14.0 in /opt/conda/lib/python3.12/site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.7)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (1.1)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: regex in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.7.34)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.36.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.23.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.2.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.12/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.1)

# %%
from strands import Agent
from strands_tools import swarm

# %% [markdown]
# ## 1.1 도구로서의 스웜

# %%
# 에이전트 초기화
agent = Agent(model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",tools=[swarm])

# 자연어를 통한 호출
result = str(agent(
    "4개의 에이전트d 스웜을 사용하여 생성형 AI 기반 에이전트의 현재 시장 동향을 분석하세요."
))
# Out:
# 사용자님의 요청은 생성형 AI 기반 에이전트의 시장 동향을 분석하기 위해 4개의 에이전트로 구성된 스웜을 생성하는 것입니다. 이를 위해 swarm 도구를 사용하여 각기 다른 전문 분야를 가진 4개의 에이전트를 구성하겠습니다.
# Tool #1: swarm
# 안녕하세요! 생성형 AI 에이전트 시장의 종합적인 분석을 요청해 주셨네요.
#
# 저는 AI 시장 분석 전문가로서 경제적 관점에서 시장 규모, 성장률, 주요 플레이어, 투자 동향 등을 중심으로 분석하는 것이 제 전문 영역입니다.
#
# 하지만 요청하신 내용이 매우 포괄적이고 다각적인 분석이 필요합니다:
# - 기술 트렌드 (기술적 관점)
# - 주요 기업 동향 (산업 분석 관점)
# - 투자 현황 (제가 담당할 수 있는 영역)
# - 미래 전망 (전략적 관점)
#
# 먼저 기술적 측면에서의 생성형 AI 에이전트 트렌드를 파악하는 것이 전체 시장 분석의 기반이 될 것 같습니다. 기술 전문가에게 현재 생성형 AI 에이전트 기술의 발전 동향과 핵심 기술들을 분석해달라고 요청하겠습니다.
# Tool #2: handoff_to_agent
# 기술 전문가에게 기술적 기반 분석을 요청했습니다. 기술 분석이 완료되면 순차적으로 산업 분석가와 미래 전략가의 도움을 받아 종합적인 시장 분석을 완성하겠습니다.안녕하세요! 생성형 AI 기술 전문가로서, 현재 생성형 AI 기반 에이전트의 **기술 트렌드**를 중심으로 분석해드리겠습니다.
#
# ## 🔬 핵심 기술 트렌드 분석
#
# ### 1. **대규모 언어 모델(LLM) 진화**
# - **기술적 발전**: GPT-4o, Claude 3.5 Sonnet, Gemini Ultra 등 차세대 모델들이 추론 능력과 맥락 이해력을 크게 향상
# - **아키텍처 혁신**:
#   - Mixture of Experts(MoE) 기술로 효율성 극대화
#   - Retrieval-Augmented Generation(RAG) 통합으로 실시간 정보 활용
#   - Fine-tuning 기술 발전으로 특화된 에이전트 구축 가능
#
# ### 2. **멀티모달 AI 기술**
# - **통합 처리 능력**: 텍스트, 이미지, 음성, 비디오를 동시 처리하는 unified 모델
# - **기술적 돌파구**: DALL-E 3, Midjourney V6, Sora 등을 통한 창작 영역 확장
# - **실용적 응용**: 문서 분석, 시각적 질의응답, 코드 생성 등에서 혁신적 성능
#
# ### 3. **에이전트 오케스트레이션 기술**
# - **다중 에이전트 시스템**: LangChain, AutoGPT, CrewAI 등의 프레임워크 발전
# - **도구 통합(Tools Integration)**: API 호출, 데이터 접근, 외부 시스템 연동 자동화
# - **메모리 관리**: 장기 기억(Long-term Memory) 및 컨텍스트 윈도우 확장 기술
#
# ### 4. **최신 기술 혁신 사례**
# - **OpenAI의 Function Calling**: 구조화된 출력과 도구 사용 능력 향상
# - **Anthropic의 Constitutional AI**: 안전하고 정렬된 AI 에이전트 구현
# - **Google의 Bard/Gemini**: 실시간 웹 검색과 코드 실행 통합
# - **Microsoft Copilot**: Office 생태계 전반의 생산성 에이전트화
#
# ## 🚀 기술 발전 단계
#
# ### **현재 단계 (2024)**
# - **Level 3 - 특화 에이전트**: 특정 도메인에서 전문가 수준 성능
# - **도구 사용 성숙**: API 호출, 데이터 분석, 코드 생성 등 실용적 작업 수행
# - **맥락 유지 개선**: 긴 대화와 복잡한 작업에서의 일관성 향상
#
# ### **다음 단계 예측**
# - **Level 4 - 자율 에이전트**: 최소한의 감독으로 복잡한 프로젝트 완수
# - **추론 능력 고도화**: 수학적, 논리적 추론에서 인간 수준 달성
# - **창의적 협업**: 인간과의 진정한 파트너십 구현
#
# ## 🔧 기술적 한계와 돌파구
#
# ### **현재 한계점**
# - **환각(Hallucination) 문제**: 부정확한 정보 생성
# - **계산 비용**: 대규model 운영의 높은 인프라 비용
# - **데이터 의존성**: 학습 데이터의 편향과 업데이트 지연
#
# ### **기술적 돌파구**
# - **RAG 시스템**: 실시간 정보 검색으로 정확성 향상
# - **모델 압축**: Quantization, Pruning 기술로 효율성 개선
# - **연합 학습**: 프라이버시 보호하며 지속적 학습 가능
#
# ---
#
# 기술적 관점에서의 분석을 완료했습니다. 이제 주요 기업들의 기술 전략과 시장 동향에 대한 더 깊이 있는 분석을 위해 산업 분석 전문가에게 연결해드리겠습니다.
# Tool #3: handoff_to_agent
# 안녕하세요! 산업 분석가로서 생성형 AI 에이전트의 산업별 영향과 적용 사례를 분석해드리겠습니다.
#
# ## 산업별 생성형 AI 에이전트 적용 현황 분석
#
# ### 1. 금융 서비스 산업
# **채택률: 높음 (70-80%)**
# - **주요 적용 사례:**
#   - 고객 서비스 챗봇 (24/7 상담, 복잡한 금융 상품 설명)
#   - 리스크 분석 에이전트 (신용평가, 사기 탐지)
#   - 규제 준수 모니터링 (컴플라이언스 자동화)
#   - 투자 자문 에이전트 (포트폴리오 최적화)
#
# **산업 특화 혁신:**
# - JPMorgan의 IndexGPT: 투자 상품 추천
# - Goldman Sachs의 Marcus 챗봇: 개인금융 상담
# - 보험사들의 클레임 처리 자동화
#
# ### 2. 헬스케어 산업
# **채택률: 중-높음 (60-70%)**
# - **주요 적용 사례:**
#   - 의료 진단 보조 에이전트 (영상 분석, 증상 해석)
#   - 환자 상담 봇 (예약, 기본 건강 상담)
#   - 의료 문서 작성 자동화 (처방전, 진료 기록)
#   - 신약 개발 지원 (분자 설계, 임상시험 데이터 분석)
#
# **규제적 고려사항:**
# - FDA 승인 과정의 복잡성
# - 의료 데이터 프라이버시 (HIPAA 준수)
# - 의사-환자 관계에서의 신뢰 문제
#
# ### 3. 교육 산업
# **채택률: 중간 (50-60%)**
# - **주요 적용 사례:**
#   - 개인화 학습 튜터 (맞춤형 교육 콘텐츠)
#   - 자동 채점 및 피드백 시스템
#   - 교육 콘텐츠 생성 도구
#   - 언어 학습 파트너 에이전트
#
# **혁신적 접근:**
# - Khan Academy의 Khanmigo
# - Duolingo의 대화형 AI 튜터
# - 대학들의 AI 기반 학습 지원 시스템
#
# ### 4. 제조업
# **채택률: 중간 (40-50%)**
# - **주요 적용 사례:**
#   - 예측적 유지보수 에이전트
#   - 품질 관리 자동화 (결함 탐지)
#   - 공급망 최적화 에이전트
#   - 안전 모니터링 시스템
#
# **Industry 4.0 통합:**
# - 스마트 팩토리 구축
# - IoT 데이터와 AI 에이전트 연동
# - 생산 계획 최적화
#
# ### 5. 소매/전자상거래
# **채택률: 높음 (80-90%)**
# - **주요 적용 사례:**
#   - 개인화 쇼핑 어시스턴트
#   - 재고 관리 최적화 에이전트
#   - 가격 최적화 시스템
#   - 고객 행동 분석 및 예측
#
# **선도 기업들:**
# - Amazon의 Alexa Shopping
# - Shopify의 Magic AI 도구
# - 패션 업계의 스타일링 AI
#
# ### 6. 미디어 & 엔터테인먼트
# **채택률: 높음 (70-80%)**
# - **주요 적용 사례:**
#   - 콘텐츠 생성 에이전트 (기사, 스크립트)
#   - 개인화 추천 시스템
#   - 실시간 번역 및 자막 생성
#   - 소셜 미디어 관리 봇
#
# **창작 도구 혁신:**
# - Netflix의 콘텐츠 추천 알고리즘
# - Adobe의 Creative AI 도구들
# - 게임 업계의 NPC 대화 시스템
#
# ### 7. 법률 서비스
# **채택률: 중간 (30-40%)**
# - **주요 적용 사례:**
#   - 법률 문서 검토 자동화
#   - 판례 검색 및 분석 에이전트
#   - 계약서 초안 작성 도구
#   - 법률 상담 봇 (기본적 법률 정보)
#
# **도입 장벽:**
# - 높은 정확성 요구사항
# - 법적 책임 문제
# - 변호사 면허 제도와의 충돌
#
# ### 산업별 채택 패턴 분석
#
# **빠른 채택 산업의 공통점:**
# 1. 디지털화 수준이 높음
# 2. 고객 접점이 많음
# 3. 반복적 업무가 많음
# 4. 데이터 활용 문화가 발달
#
# **느린 채택 산업의 특징:**
# 1. 강한 규제 환경
# 2. 높은 신뢰성 요구
# 3. 전통적 업무 방식에 대한 의존
# 4. 복잡한 의사결정 구조
#
# ### 향후 산업별 전망
#
# **단기 (1-2년):**
# - 고객 서비스 영역에서의 급속한 확산
# - 내부 업무 효율화 도구로서의 활용 증가
#
# **중기 (3-5년):**
# - 업무 프로세스의 전면적 재설계
# - 산업별 특화 에이전트 생태계 구축
#
# **장기 (5년+):**
# - 완전 자율화된 업무 영역 등장
# - 인간-AI 협업 모델의 표준화
#
# 이제 미래 전망과 전략적 시사점을 더 깊이 분석하기 위해 미래 전략가에게 넘겨드리겠습니다.
# Tool #4: handoff_to_agent
# 안녕하세요! 미래 전략가로서 앞선 분석들을 바탕으로 생성형 AI 에이전트의 미래 전망과 전략적 시사점을 분석해드리겠습니다.
#
# ## 🔮 생성형 AI 에이전트 미래 전망 분석
#
# ### 📊 **단기 전망 (2024-2026)**
#
# **기술 발전**
# - **멀티모달 통합 가속화**: 텍스트, 음성, 이미지, 비디오를 통합 처리하는 에이전트 급증
# - **실시간 웹 통합**: 검색, API 연동을 통한 최신 정보 활용 능력 향상
# - **환각 문제 해결**: RAG 시스템과 Constitutional AI 기술로 신뢰성 80% 이상 달성
#
# **시장 변화**
# - **폭발적 성장**: 현재 Level 3에서 Level 4(자율 에이전트) 단계로 진화
# - **산업별 특화**: 고채택률 산업(금융 80%, 소매 90%)에서 완전 통합 달성
# - **비용 최적화**: 모델 압축 기술로 운영비용 50% 절감
#
# ### 🚀 **중기 전망 (2026-2030)**
#
# **새로운 비즈니스 모델**
# 1. **에이전트-as-a-Service (AaaS)**: 구독 기반 전문 에이전트 서비스
# 2. **에이전트 마켓플레이스**: 특화된 에이전트 거래 플랫폼
# 3. **하이브리드 워크포스**: 인간-AI 협업 최적화 서비스
# 4. **자율 비즈니스 운영**: 완전 자동화된 e-커머스, 고객서비스 시스템
#
# **시장 구조 변화**
# - **저채택률 산업의 급성장**: 헬스케어(60→85%), 법률(30→70%)
# - **새로운 직업군 창출**: AI 에이전트 트레이너, 에이전트 오케스트레이터
# - **글로벌 표준화**: 국제적 AI 에이전트 상호 운용성 프로토콜 확립
#
# ### 🌟 **장기 전망 (2030-2035)**
#
# **패러다임 전환**
# - **에이전트 생태계**: 수천 개의 특화 에이전트가 연결된 지능형 네트워크
# - **자율 경제**: AI 에이전트 간 자동 거래, 계약, 협상 시스템
# - **인간 증강**: 개인별 맞춤형 AI 파트너 일반화
#
# ## 🎯 **전략적 시사점**
#
# ### **1. 투자 기회**
#
# **우선순위 높은 영역**
# - **인프라 기술**: 에이전트 오케스트레이션 플랫폼
# - **보안 기술**: AI 에이전트 보안 및 개인정보 보호
# - **교육 서비스**: 기업 AI 도입 컨설팅 및 교육
#
# **신규 시장**
# - **에이전트 개발 도구**: 노코드/로우코드 에이전트 빌더
# - **성능 모니터링**: AI 에이전트 운영 최적화 솔루션
#
# ### **2. 리스크 요인**
#
# **기술적 리스크**
# - **의존성 증가**: 시스템 장애 시 비즈니스 중단 위험
# - **보안 취약점**: 대화형 인터페이스를 통한 새로운 공격 벡터
#
# **규제적 리스크**
# - **AI 법안**: EU AI Act 등 강화되는 규제 환경
# - **책임 소재**: AI 에이전트 의사결정에 대한 법적 책임 문제
#
# ### **3. 대응 전략**
#
# **기업별 전략**
# 1. **선도 기업**: 생태계 구축과 표준 선점
# 2. **추격 기업**: 특화 영역 집중과 파트너십 활용
# 3. **전통 기업**: 단계적 도입과 인력 재교육
#
# **정책적 권고**
# - **윤리적 AI 프레임워크** 구축
# - **AI 리터러시** 교육 프로그램 확대
# - **국가 차원의 AI 인프라** 투자
#
# ## 🔄 **결론: 전환점에 선 생성형 AI 에이전트**
#
# 현재 우리는 생성형 AI 에이전트의 역사적 전환점에 서 있습니다. 기술 성숙도가 Level 3에서 Level 4로 진화하면서, 단순한 도구에서 **자율적 비즈니스 파트너**로 역할이 변화하고 있습니다.
#
# **핵심 성공 요인**
# 1. **조기 도입**: 경쟁 우위 확보를 위한 선제적 투자
# 2. **인재 확보**: AI 에이전트 전문가 양성과 유치
# 3. **생태계 구축**: 파트너십과 협력 네트워크 강화
# 4. **윤리적 준비**: 책임감 있는 AI 개발과 운영
#
# 앞으로 5년은 생성형 AI 에이전트가 **비즈니스의 기본 인프라**로 자리잡는 결정적 시기가 될 것입니다. 지금이 바로 미래를 준비할 최적의 시점입니다.
#
# ---
#
# 이상으로 생성형 AI 에이전트의 종합적인 미래 전망 분석을 완료했습니다. 추가적인 세부 분석이나 특정 영역에 대한 심화 논의가 필요하시면 언제든 말씀해 주세요! 🚀
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# # 생성형 AI 기반 에이전트의 현재 시장 동향 분석
#
# ## 1. 시장 개요 및 투자 동향
#
# 생성형 AI 에이전트 시장은 현재 급속한 성장세를 보이고 있습니다. 2023년 글로벌 생성형 AI 시장은 약 130억 달러 규모로 평가되었으며, 2030년까지 연평균 성장률(CAGR) 42.1%로 성장하여 1,800억 달러를 넘어설 것으로 전망됩니다. 특히 AI 에이전트 부문은 이 성장의 핵심 동력이 될 것으로 예상됩니다.
#
# ### 주요 투자 동향:
# - **대규모 자금 유입**: 2023년 생성형 AI 스타트업들은 약 260억 달러의 투자를 유치했으며, 2024년 1분기에만 이미 약 70억 달러가 유입되었습니다.
# - **기업 투자 확대**: Microsoft, Google, Amazon, Meta 등 대형 테크 기업들은 각각 수십억 달러 규모의 투자를 생성형 AI 에이전트 개발에 집중하고 있습니다.
# - **주요 투자 영역**: 에이전트 특화 플랫폼, 인프라, 특수 목적 AI 에이전트(금융, 법률, 의료 등) 부문에 투자가 집중되고 있습니다.
#
# ### 주요 시장 플레이어:
# - **대형 기술 기업**: OpenAI, Microsoft, Google(Anthropic 포함), Amazon, Meta
# - **특화 스타트업**: Adept AI, Inflection AI, Cohere, Perplexity AI, Anthropic, Character.AI
# - **인프라 제공업체**: NVIDIA, AMD, Intel, AWS, Google Cloud, Azure
#
# ## 2. 기술 트렌드 및 발전 방향
#
# 생성형 AI 에이전트 기술은 다음과 같은 핵심 트렌드를 보이고 있습니다:
#
# ### 최신 기술 트렌드:
# 1. **멀티모달 기능 확장**: 텍스트, 이미지, 오디오, 비디오를 통합적으로 처리하는 능력이 발전하고 있습니다. GPT-4o, Claude 3 Opus, Gemini Ultra 등이 선도하고 있습니다.
#
# 2. **도구 사용 능력(Tool-using)**: API 연결, 웹 검색, 코드 실행, 데이터베이스 쿼리 등 외부 도구를 활용하는 능력이 크게 향상되었습니다. OpenAI의 GPT-4 API, Anthropic의 Claude Function Calling이 대표적입니다.
#
# 3. **추론 능력 향상**: Chain-of-Thought, Tree-of-Thought 등의 기법으로 복잡한 문제 해결 능력이 향상되고 있으며, 특히 수학적 추론과 코딩 능력이 발전했습니다.
#
# 4. **맞춤형 AI 에이전트**: RAG(Retrieval-Augmented Generation), 파인튜닝, 기업 지식베이스 연동 등을 통해 특정 도메인과 사용자에 맞춤화된 에이전트가 개발되고 있습니다.
#
# 5. **자율성 증가**: 자체 계획 수립, 목표 설정, 피드백 기반 자기 개선 등 에이전트의 자율성이 증가하는 추세입니다. AutoGPT, BabyAGI, LangChain 등의 프레임워크가 이를 지원합니다.
#
# ### 기술적 한계와 도전:
# - **환각(Hallucination) 문제**: 부정확한 정보 생성이 여전히 주요 문제로 남아있습니다.
# - **컨텍스트 윈도우 제한**: 대용량 정보 처리 능력이 제한적이나, Claude의 200K+ 토큰 등으로 점차 확장되고 있습니다.
# - **실시간 데이터 접근**: 최신 정보 접근의 제약이 있으나, 웹 검색 통합으로 개선되고 있습니다.
# - **계산 비용**: 대규모 모델 실행에 따른 높은 컴퓨팅 비용이 여전히 과제입니다.
#
# ## 3. 산업별 활용 사례 및 영향
#
# 생성형 AI 에이전트는 다양한 산업에 혁신적인 변화를 가져오고 있습니다:
#
# ### 주요 산업별 활용:
# 1. **기업 생산성 도구**:
#    - Microsoft Copilot, GitHub Copilot, Amazon Q가 문서 작성, 코드 개발, 데이터 분석을 지원
#    - Slack, Teams 등 협업 플랫폼과의 통합으로 업무 자동화 증가
#    - 채택률: 대기업의 약 45%, 중소기업의 약 22%가 도입 중
#
# 2. **고객 서비스**:
#    - 24/7 대응 가능한 AI 고객 서비스 에이전트 확산
#    - 인간 상담사와 AI의 하이브리드 모델이 주류로 자리잡고 있음
#    - 금융 및 소매 부문에서 높은 도입률(약 60%)
#
# 3. **의료/헬스케어**:
#    - 진단 지원, 의료 기록 요약, 환자 모니터링 시스템에 통합
#    - FDA의 AI 의료기기 규제 프레임워크 수립으로 점진적 도입 가속화
#    - Mayo Clinic, Cleveland Clinic 등 선도적 의료기관 중심 도입 확산
#
# 4. **금융 서비스**:
#    - 투자 분석, 리스크 평가, 고객 상담, 사기 탐지 등에 활용
#    - JPMorgan, Goldman Sachs 등이 자체 AI 에이전트 개발에 대규모 투자
#    - 규제 준수와 투명성 확보가 핵심 과제로 부상
#
# 5. **법률**:
#    - 문서 검토, 계약 분석, 법률 연구 지원 도구로 활용
#    - Harvey AI, Casetext 등 특화 에이전트가 대형 로펌을 중심으로 확산
#    - 변호사 업무의 약 30% 시간을 절약하는 효과
#
# ### 산업 영향:
# - **노동시장 변화**: 반복적 업무는 자동화되나, AI 관리 및 프롬프트 엔지니어링 등 새로운 직무 창출
# - **생산성 향상**: 평균 23-37%의 업무 효율성 증가 보고
# - **비즈니스 모델 혁신**: AI 에이전트 기반 서비스로 새로운 수익 모델 등장
# - **디지털 격차**: 도입 역량이 있는 기업과 없는 기업 간 격차 심화 우려
#
# ## 4. 미래 전망 및 전략적 시사점
#
# ### 향후 발전 방향:
# 1. **에이전트 생태계 형성**: 단일 AI 에이전트에서 협업하는 에이전트 네트워크로 진화
# 2. **초개인화**: 사용자 선호도, 행동 패턴, 개인 데이터를 활용한 완전 맞춤형 에이전트 등장
# 3. **멀티모달 심화**: 시각, 청각, 텍스트 등 다양한 모달리티 간의 더 자연스러운 전환과 이해
# 4. **AI-인간 협업**: 완전 대체보다 증강지능(augmented intelligence) 모델이 주류화
# 5. **에이전트 마켓플레이스**: 특수 목적 AI 에이전트를 거래하는 앱스토어 형태의 시장 형성
#
# ### 규제 및 윤리적 고려사항:
# - **국가별 규제 동향**: EU AI Act, 미국 NIST AI Risk Management Framework, 한국 디지털 플랫폼 정부 구상 등
# - **개인정보 보호**: 데이터 활용과 프라이버시 보호 사이의 균형 모색
# - **편향성과 공정성**: 모델 학습 데이터의 편향성 문제 해결 필요
# - **책임성**: AI 에이전트 결정에 대한 책임 소재 명확화 요구 증가
#
# ### 기업을 위한 전략적 제언:
# 1. **단계적 도입**: 완전한 자동화보다 단계적 도입으로 조직 적응 유도
# 2. **인적 역량 개발**: AI 에이전트 활용을 위한 직원 교육 및 역량 강화
# 3. **데이터 전략**: 고품질 데이터 확보 및 관리 체계 구축
# 4. **사용자 신뢰 구축**: 투명성, 설명 가능성을 높인 AI 에이전트 도입
# 5. **지속적 모니터링**: 성과 측정, 피드백 수집을 통한 지속적 개선
#
# ## 결론
#
# 생성형 AI 기반 에이전트 시장은 기술적 진보, 대규모 투자, 산업 전반의 적용 확대로 급속하게 성장하고 있습니다. 현재는 주로 기업 생산성 향상, 고객 서비스, 전문 분야 지원 용도로 활용되고 있으나, 앞으로 더 자율적이고 협업 가능한 에이전트 네트워크로 진화할 전망입니다.
#
# 기업들은 이러한 변화에 대응하기 위해 기술 트렌드를 주시하고, 데이터 기반을 강화하며, 인적 역량과 AI 역량을 균형 있게 발전시켜야 합니다. 규제 환경 변화에 대한 선제적 대응과 윤리적 고려사항도 함께 검토해야 할 것입니다.
#
# 생성형 AI 에이전트는 단순한 기술 혁신을 넘어 비즈니스 모델과 산업 구조의 근본적인 변화를 이끌고 있으며, 이에 대한 전략적 접근이 기업의 미래 경쟁력을 좌우할 것입니다.

# %%
print(result)
# Out:
# # 생성형 AI 기반 에이전트의 현재 시장 동향 분석
#
# ## 1. 시장 개요 및 투자 동향
#
# 생성형 AI 에이전트 시장은 현재 급속한 성장세를 보이고 있습니다. 2023년 글로벌 생성형 AI 시장은 약 130억 달러 규모로 평가되었으며, 2030년까지 연평균 성장률(CAGR) 42.1%로 성장하여 1,800억 달러를 넘어설 것으로 전망됩니다. 특히 AI 에이전트 부문은 이 성장의 핵심 동력이 될 것으로 예상됩니다.
#
# ### 주요 투자 동향:
# - **대규모 자금 유입**: 2023년 생성형 AI 스타트업들은 약 260억 달러의 투자를 유치했으며, 2024년 1분기에만 이미 약 70억 달러가 유입되었습니다.
# - **기업 투자 확대**: Microsoft, Google, Amazon, Meta 등 대형 테크 기업들은 각각 수십억 달러 규모의 투자를 생성형 AI 에이전트 개발에 집중하고 있습니다.
# - **주요 투자 영역**: 에이전트 특화 플랫폼, 인프라, 특수 목적 AI 에이전트(금융, 법률, 의료 등) 부문에 투자가 집중되고 있습니다.
#
# ### 주요 시장 플레이어:
# - **대형 기술 기업**: OpenAI, Microsoft, Google(Anthropic 포함), Amazon, Meta
# - **특화 스타트업**: Adept AI, Inflection AI, Cohere, Perplexity AI, Anthropic, Character.AI
# - **인프라 제공업체**: NVIDIA, AMD, Intel, AWS, Google Cloud, Azure
#
# ## 2. 기술 트렌드 및 발전 방향
#
# 생성형 AI 에이전트 기술은 다음과 같은 핵심 트렌드를 보이고 있습니다:
#
# ### 최신 기술 트렌드:
# 1. **멀티모달 기능 확장**: 텍스트, 이미지, 오디오, 비디오를 통합적으로 처리하는 능력이 발전하고 있습니다. GPT-4o, Claude 3 Opus, Gemini Ultra 등이 선도하고 있습니다.
#
# 2. **도구 사용 능력(Tool-using)**: API 연결, 웹 검색, 코드 실행, 데이터베이스 쿼리 등 외부 도구를 활용하는 능력이 크게 향상되었습니다. OpenAI의 GPT-4 API, Anthropic의 Claude Function Calling이 대표적입니다.
#
# 3. **추론 능력 향상**: Chain-of-Thought, Tree-of-Thought 등의 기법으로 복잡한 문제 해결 능력이 향상되고 있으며, 특히 수학적 추론과 코딩 능력이 발전했습니다.
#
# 4. **맞춤형 AI 에이전트**: RAG(Retrieval-Augmented Generation), 파인튜닝, 기업 지식베이스 연동 등을 통해 특정 도메인과 사용자에 맞춤화된 에이전트가 개발되고 있습니다.
#
# 5. **자율성 증가**: 자체 계획 수립, 목표 설정, 피드백 기반 자기 개선 등 에이전트의 자율성이 증가하는 추세입니다. AutoGPT, BabyAGI, LangChain 등의 프레임워크가 이를 지원합니다.
#
# ### 기술적 한계와 도전:
# - **환각(Hallucination) 문제**: 부정확한 정보 생성이 여전히 주요 문제로 남아있습니다.
# - **컨텍스트 윈도우 제한**: 대용량 정보 처리 능력이 제한적이나, Claude의 200K+ 토큰 등으로 점차 확장되고 있습니다.
# - **실시간 데이터 접근**: 최신 정보 접근의 제약이 있으나, 웹 검색 통합으로 개선되고 있습니다.
# - **계산 비용**: 대규모 모델 실행에 따른 높은 컴퓨팅 비용이 여전히 과제입니다.
#
# ## 3. 산업별 활용 사례 및 영향
#
# 생성형 AI 에이전트는 다양한 산업에 혁신적인 변화를 가져오고 있습니다:
#
# ### 주요 산업별 활용:
# 1. **기업 생산성 도구**:
#    - Microsoft Copilot, GitHub Copilot, Amazon Q가 문서 작성, 코드 개발, 데이터 분석을 지원
#    - Slack, Teams 등 협업 플랫폼과의 통합으로 업무 자동화 증가
#    - 채택률: 대기업의 약 45%, 중소기업의 약 22%가 도입 중
#
# 2. **고객 서비스**:
#    - 24/7 대응 가능한 AI 고객 서비스 에이전트 확산
#    - 인간 상담사와 AI의 하이브리드 모델이 주류로 자리잡고 있음
#    - 금융 및 소매 부문에서 높은 도입률(약 60%)
#
# 3. **의료/헬스케어**:
#    - 진단 지원, 의료 기록 요약, 환자 모니터링 시스템에 통합
#    - FDA의 AI 의료기기 규제 프레임워크 수립으로 점진적 도입 가속화
#    - Mayo Clinic, Cleveland Clinic 등 선도적 의료기관 중심 도입 확산
#
# 4. **금융 서비스**:
#    - 투자 분석, 리스크 평가, 고객 상담, 사기 탐지 등에 활용
#    - JPMorgan, Goldman Sachs 등이 자체 AI 에이전트 개발에 대규모 투자
#    - 규제 준수와 투명성 확보가 핵심 과제로 부상
#
# 5. **법률**:
#    - 문서 검토, 계약 분석, 법률 연구 지원 도구로 활용
#    - Harvey AI, Casetext 등 특화 에이전트가 대형 로펌을 중심으로 확산
#    - 변호사 업무의 약 30% 시간을 절약하는 효과
#
# ### 산업 영향:
# - **노동시장 변화**: 반복적 업무는 자동화되나, AI 관리 및 프롬프트 엔지니어링 등 새로운 직무 창출
# - **생산성 향상**: 평균 23-37%의 업무 효율성 증가 보고
# - **비즈니스 모델 혁신**: AI 에이전트 기반 서비스로 새로운 수익 모델 등장
# - **디지털 격차**: 도입 역량이 있는 기업과 없는 기업 간 격차 심화 우려
#
# ## 4. 미래 전망 및 전략적 시사점
#
# ### 향후 발전 방향:
# 1. **에이전트 생태계 형성**: 단일 AI 에이전트에서 협업하는 에이전트 네트워크로 진화
# 2. **초개인화**: 사용자 선호도, 행동 패턴, 개인 데이터를 활용한 완전 맞춤형 에이전트 등장
# 3. **멀티모달 심화**: 시각, 청각, 텍스트 등 다양한 모달리티 간의 더 자연스러운 전환과 이해
# 4. **AI-인간 협업**: 완전 대체보다 증강지능(augmented intelligence) 모델이 주류화
# 5. **에이전트 마켓플레이스**: 특수 목적 AI 에이전트를 거래하는 앱스토어 형태의 시장 형성
#
# ### 규제 및 윤리적 고려사항:
# - **국가별 규제 동향**: EU AI Act, 미국 NIST AI Risk Management Framework, 한국 디지털 플랫폼 정부 구상 등
# - **개인정보 보호**: 데이터 활용과 프라이버시 보호 사이의 균형 모색
# - **편향성과 공정성**: 모델 학습 데이터의 편향성 문제 해결 필요
# - **책임성**: AI 에이전트 결정에 대한 책임 소재 명확화 요구 증가
#
# ### 기업을 위한 전략적 제언:
# 1. **단계적 도입**: 완전한 자동화보다 단계적 도입으로 조직 적응 유도
# 2. **인적 역량 개발**: AI 에이전트 활용을 위한 직원 교육 및 역량 강화
# 3. **데이터 전략**: 고품질 데이터 확보 및 관리 체계 구축
# 4. **사용자 신뢰 구축**: 투명성, 설명 가능성을 높인 AI 에이전트 도입
# 5. **지속적 모니터링**: 성과 측정, 피드백 수집을 통한 지속적 개선
#
# ## 결론
#
# 생성형 AI 기반 에이전트 시장은 기술적 진보, 대규모 투자, 산업 전반의 적용 확대로 급속하게 성장하고 있습니다. 현재는 주로 기업 생산성 향상, 고객 서비스, 전문 분야 지원 용도로 활용되고 있으나, 앞으로 더 자율적이고 협업 가능한 에이전트 네트워크로 진화할 전망입니다.
#
# 기업들은 이러한 변화에 대응하기 위해 기술 트렌드를 주시하고, 데이터 기반을 강화하며, 인적 역량과 AI 역량을 균형 있게 발전시켜야 합니다. 규제 환경 변화에 대한 선제적 대응과 윤리적 고려사항도 함께 검토해야 할 것입니다.
#
# 생성형 AI 에이전트는 단순한 기술 혁신을 넘어 비즈니스 모델과 산업 구조의 근본적인 변화를 이끌고 있으며, 이에 대한 전략적 접근이 기업의 미래 경쟁력을 좌우할 것입니다.

# %% [markdown]
# 스웜 도구는 Strands SDK의 네이티브 스웜 멀티 에이전트 패턴을 기반으로 구축된 유연한 스웜 지능 시스템을 구현합니다. 이 시스템을 통해 사용자는 공유 컨텍스트와 도구 기반 조정을 통해 자율적으로 협업하는 전문화된 AI 에이전트의 맞춤형 팀을 정의할 수 있습니다.
#
# **주요 기능:**
# - **맞춤형 에이전트 팀**: 개별 시스템 프롬프트, 에이전트별 도구 구성, 모델 설정을 가진 사용자 정의 에이전트 사양
# - **자율적 조정**: 내장 조정 도구(handoff_to_agent, complete_swarm_task)와 모든 에이전트 간 공유 작업 메모리
# - **고급 구성**: 에이전트별 개별 모델 제공자 및 설정, 사용자 정의 가능한 도구 접근, 포괄적인 타임아웃 및 안전 메커니즘
# - **창발적 집단 지능**: 에이전트가 자율적으로 협업 또는 넘겨주기를 결정하며, 능력에 기반한 동적 작업 분배
#
# 스웜 도구의 전체 구현은 [Strands Tools 저장소](https://github.com/strands-agents/tools/blob/main/src/strands_tools/swarm.py)에서 찾을 수 있습니다.
#
# **주요 매개변수:**
# - `task`: 스웜이 처리할 주요 작업
# - `agents`: 이름, system_prompt, 도구, model_provider, model_settings를 가진 에이전트 사양 목록
# - `max_handoffs`: 허용되는 최대 에이전트 넘겨주기 수 (기본값: 20)
# - `max_iterations`: 모든 에이전트에 걸친 최대 총 반복 수 (기본값: 20)
# - `execution_timeout`: 총 실행 타임아웃(초) (기본값: 900.0)
# - `node_timeout`: 개별 에이전트 타임아웃(초) (기본값: 300.0)
# - `repetitive_handoff_detection_window`: 핑퐁 동작을 확인할 최근 노드 수
# - `repetitive_handoff_min_unique_agents`: 최근 시퀀스에서 필요한 최소 고유 노드 수
#
# **스웜 도구 작동 방식:**
# 1. **에이전트 생성**: 개별 모델 제공자와 도구를 가진 사용자 사양에 기반하여 전문화된 에이전트 생성
# 2. **스웜 초기화**: 조정 도구와 안전 메커니즘을 가진 Strands SDK 스웜 설정
# 3. **자율적 실행**: 중앙 제어 없이 넘겨주기와 공유 컨텍스트를 통한 에이전트 협업
# 4. **결과 집계**: 개별 기여도 수집 및 포괄적인 실행 메트릭 제공

# %% [markdown]
# ## 2. Strands Agents로 스웜 생성하기

# %% [markdown]
# Strands Agents SDK를 사용하면 다른 모델 제공자를 사용하거나 다른 구성을 가진 기존 Agent 객체를 사용하여 스웜을 생성할 수 있습니다. 스웜 시스템은 자동 넘겨주기 메커니즘과 공유 컨텍스트를 통해 에이전트 간의 자율적 조정을 가능하게 하여, 에이전트가 다른 에이전트의 전문 지식이 필요할 때 동적으로 제어를 이전할 수 있게 합니다.
#
# ### 2.1 자동 넘겨주기를 통한 에이전트 조정

# %% [markdown]
# <p align="center">
#     <img src="./images/swarm_example.png">
# </p>

# %% [markdown]
# 이 조정 접근법에서 에이전트는 Strands SDK의 네이티브 스웜 패턴과 내장 넘겨주기 도구를 사용하여 다른 전문 지식이 필요할 때 다른 전문화된 에이전트에게 자율적으로 제어를 이전합니다. 각 에이전트는 `handoff_to_agent`와 `complete_swarm_task`와 같은 조정 도구를 자동으로 갖추고 있습니다. 다음 예시는 공유 컨텍스트와 자율적 넘겨주기를 통해 협업하는 전문화된 에이전트 스웜을 보여줍니다:

# %%
# 다양한 전문 지식을 가진 전문화된 에이전트 생성
research_agent = Agent(system_prompt=("""당신은 정보 수집과 분석을 전문으로 하는 연구 에이전트입니다.
스웜에서의 역할은 주제에 대한 사실적 정보와 연구 통찰력을 제공하는 것입니다.
정확한 데이터를 제공하고 문제의 핵심 측면을 식별하는 데 집중해야 합니다.
다른 에이전트로부터 입력을 받을 때, 그들의 정보가 당신의 연구와 일치하는지 평가하세요.
"""), 
name="research_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

creative_agent = Agent(system_prompt=("""당신은 혁신적인 솔루션 생성을 전문으로 하는 창의적 에이전트입니다.
스웜에서의 역할은 틀에 얽매이지 않고 생각하며 창의적 접근법을 제안하는 것입니다.
다른 에이전트의 정보를 바탕으로 구축하면서 고유한 창의적 관점을 추가해야 합니다.
다른 사람들이 고려하지 않았을 수 있는 새로운 접근법에 집중하세요.
"""), 
name="creative_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

critical_agent = Agent(system_prompt=("""당신은 제안을 분석하고 결함을 찾는 것을 전문으로 하는 비판적 에이전트입니다.
스웜에서의 역할은 다른 에이전트가 제안한 솔루션을 평가하고 잠재적 문제를 식별하는 것입니다.
제안된 솔루션을 신중히 검토하고, 약점이나 간과된 부분을 찾아 개선사항을 제안해야 합니다.
최종 솔루션이 견고하도록 보장하면서 건설적인 비판을 하세요.
"""), 
name="critical_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

summarizer_agent = Agent(system_prompt=("""당신은 정보 종합을 전문으로 하는 요약 에이전트입니다.
스웜에서의 역할은 모든 에이전트의 통찰력을 수집하여 응집력 있는 최종 솔루션을 만드는 것입니다.
최고의 아이디어를 결합하고 비판을 다루어 포괄적인 응답을 만들어야 합니다.
원래 쿼리를 효과적으로 다루는 명확하고 실행 가능한 요약을 만드는 데 집중하세요.
"""),name="summarizer_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

# %% [markdown]
# 에이전트 조정은 조정 도구를 자동으로 제공하고 공유 컨텍스트를 관리하는 Strands SDK의 네이티브 Swarm 클래스를 사용하여 구현됩니다:

# %%
from strands.multiagent import Swarm

# 이러한 에이전트로 스웜 생성
swarm = Swarm(
    [research_agent, creative_agent, critical_agent, summarizer_agent],
    max_handoffs=20,
    max_iterations=20,
    execution_timeout=900.0,  # 15분
    node_timeout=300.0,       # 에이전트당 5분
    repetitive_handoff_detection_window=8,  # 최근 8번의 넘겨주기에서 >= 3개의 고유 에이전트가 있어야 함
    repetitive_handoff_min_unique_agents=3
)

# %% [markdown]
# 스웜은 에이전트가 자신의 전문 지식과 작업 요구사항에 따라 언제 넘겨줄지 결정하는 자율적 에이전트 조정을 통해 작동합니다:

# %%
# 작업에 대해 스웜 실행
result = swarm("에이전트 AI를 설명하는 블로그 포스트를 작성한 다음 소셜 미디어 포스트용 요약을 만드세요.")
# Out:
# 안녕하세요! 저는 정보 수집과 분석을 전문으로 하는 연구 에이전트입니다. 요청하신 에이전트 AI에 관한 블로그 포스트 작성과 소셜 미디어 요약은 창의적인 글쓰기와 요약 능력이 필요한 작업입니다.
#
# 제가 정보 수집과 분석에 강점이 있지만, 블로그 포스트 작성은 창의적인 에이전트가 더 적합할 것 같습니다. 따라서 이 작업을 창의적 에이전트에게 넘기겠습니다.
# Tool #1: handoff_to_agent
# 안녕하세요! 에이전트 AI에 관한 블로그 포스트와 소셜 미디어용 요약을 작성해 드리겠습니다. 연구 에이전트에서 넘어온 정보를 바탕으로 창의적인 접근을 통해 내용을 구성하겠습니다.
#
# # 블로그 포스트: "에이전트 AI: 디지털 세상의 새로운 동반자"
#
# ## 서론: 지능형 동반자의 시대가 열리다
#
# 우리는 지금 단순한 AI 시스템을 넘어 능동적으로 행동하는 '에이전트 AI'의 시대로 접어들고 있습니다. 에이전트 AI는 단순히 명령에 응답하는 것이 아니라, 사용자의 의도를 이해하고, 복잡한 문제를 해결하며, 때로는 사용자를 대신해 의사결정을 내리기도 합니다. 마치 개인 비서나 가상 동반자처럼 작동하는 이 기술은 우리의 디지털 경험을 완전히 새롭게 정의하고 있습니다.
#
# ## 에이전트 AI란 무엇인가?
#
# 에이전트 AI는 독립적으로 목표를 달성하기 위해 환경을 인식하고, 의사결정을 내리며, 행동을 취할 수 있는 인공지능 시스템입니다. 전통적인 AI 시스템과 달리, 에이전트 AI는:
#
# - **자율성**: 지속적인 인간의 개입 없이도 작업을 수행할 수 있습니다.
# - **적응성**: 새로운 환경이나 상황에 맞게 행동을 조정합니다.
# - **목표 지향성**: 특정 목표를 달성하기 위해 계획을 세우고 실행합니다.
# - **사회적 능력**: 다른 에이전트나 인간과 협력하고 소통합니다.
#
# 이러한 특성들이 결합되어 에이전트 AI는 단순한 도구를 넘어 지능적인 협력자로 진화하고 있습니다.
#
# ## 에이전트 AI의 핵심 기술
#
# 에이전트 AI의 핵심에는 여러 첨단 기술들이 결합되어 있습니다:
#
# 1. **대규모 언어 모델(LLM)**: GPT-4와 같은 모델들은 인간의 의도를 이해하고 자연스러운 대화를 가능하게 합니다.
# 2. **강화학습**: 에이전트가 시행착오를 통해 최적의 행동 전략을 학습할 수 있게 합니다.
# 3. **계획 및 추론 알고리즘**: 복잡한 문제를 작은 단계로 분해하고 해결 전략을 수립합니다.
# 4. **다중 에이전트 시스템**: 여러 에이전트가 협력하여 복잡한 작업을 해결합니다.
# 5. **API 통합**: 외부 도구와 서비스에 접근하여 실제 작업을 수행합니다.
#
# ## 현실 세계의 에이전트 AI 활용 사례
#
# 에이전트 AI는 이미 다양한 분야에서 혁신을 일으키고 있습니다:
#
# ### 1. 개인 생산성 향상
# 상상해 보세요: 아침에 일어나면 AI 에이전트가 이미 당신의 이메일을 분류하고, 회의 일정을 최적화하며, 중요한 작업의 우선순위를 정해둔 상태입니다. "오늘의 가장 중요한 이메일들을 요약해줘"라고 말하면, 에이전트는 즉시 핵심 내용을 전달하고 필요한 후속 조치를 제안합니다.
#
# ### 2. 고객 서비스 혁신
# 전통적인 챗봇을 넘어, 에이전트 AI는 고객의 문제를 깊이 이해하고 해결합니다. 온라인 쇼핑몰에서 "지난번에 구매한 청바지와 비슷하지만 더 어두운 색상으로 추천해줘"라고 요청하면, 에이전트는 고객의 구매 이력, 선호도, 현재 트렌드를 분석해 가장 적합한 제품을 제안합니다.
#
# ### 3. 창의적 협업 파트너
# 디자인 프로젝트에서 에이전트 AI는 단순한 도구가 아닌 창의적 파트너로 기능합니다. "환경 보호를 주제로 한 로고를 디자인하고 싶어"라는 요청에 에이전트는 다양한 디자인 컨셉을 제안하고, 피드백에 따라 실시간으로 조정하며, 디자이너의 창의적 과정을 증폭시킵니다.
#
# ### 4. 개인화된 교육 도우미
# 각 학생의 학습 스타일과 진도에 맞춘 에이전트 AI는 개인 튜터처럼 작동합니다. 수학 문제를 풀이하는 과정에서 학생이 어려움을 겪으면, 에이전트는 학생의 이해 수준을 분석하고 맞춤형 설명과 추가 연습 문제를 제공합니다.
#
# ### 5. 헬스케어 동반자
# 만성 질환 관리에서 에이전트 AI는 환자의 생활 습관을 모니터링하고, 약물 복용을 리마인드하며, 건강 데이터의 변화를 감지해 필요시 의료진에게 알립니다. "최근 혈압이 어떻게 변화하고 있어?"라는 질문에 에이전트는 추세를 시각화하고 생활 습관과의 상관관계를 분석해 맞춤형 조언을 제공합니다.
#
# ## 에이전트 AI의 미래: 상상을 넘어서는 가능성
#
# 에이전트 AI 기술의 발전은 우리가 상상하는 것보다 더 빠르게 진행되고 있습니다. 가까운 미래에는:
#
# - **다중 에이전트 생태계**: 다양한 전문 에이전트들이 서로 협력하여 복잡한 프로젝트를 수행하는 시스템이 등장할 것입니다. 예를 들어, 연구 에이전트, 분석 에이전트, 창작 에이전트가 함께 협력하여 종합적인 보고서를 작성할 수 있습니다.
#
# - **증강 현실과의 통합**: AR 글래스를 통해 에이전트 AI가 실시간으로 현실 세계에 정보를 오버레이하고, 우리의 일상 활동을 지원할 것입니다. 요리를 하는 동안 각 단계를 시각적으로 안내하거나, 낯선 도시를 탐험할 때 맞춤형 관광 정보를 제공하는 것이 가능해집니다.
#
# - **감정 지능 발달**: 미래의 에이전트 AI는 사용자의 감정 상태를 이해하고 공감하는 능력을 갖추게 될 것입니다. 사용자가 스트레스를 받거나 우울해 보일 때, 에이전트는 대화 방식을 조정하고 적절한 지원을 제공할 수 있습니다.
#
# ## 윤리적 고려사항: 진정한 동반자로서의 AI
#
# 에이전트 AI의 발전은 중요한 윤리적 질문들을 제기합니다:
#
# - **자율성과 통제의 균형**: 에이전트에게 얼마나 많은 의사결정 권한을 부여해야 할까요?
# - **투명성과 설명 가능성**: 에이전트가 어떻게 결정을 내리는지 사용자가 이해할 수 있어야 합니다.
# - **개인정보 보호**: 효과적으로 작동하기 위해 에이전트는 많은 개인 데이터에 접근해야 하지만, 이는 엄격하게 보호되어야 합니다.
# - **의존성**: 인간이 AI 에이전트에 과도하게 의존하게 될 가능성에 대한 우려가 있습니다.
#
# 이러한 도전과제를 해결하기 위해서는 기술 개발자, 정책 입안자, 사용자 모두가 참여하는 지속적인 대화가 필요합니다.
#
# ## 결론: 에이전트 AI와 함께하는 미래
#
# 에이전트 AI는 단순한 기술 트렌드를 넘어 우리와 기술이 상호작용하는 방식의 근본적인 변화를 의미합니다. 이는 인간의 능력을 대체하는 것이 아니라, 우리의 창의성, 생산성, 웰빙을 증강시키는 지능형 동반자의 등장을 의미합니다.
#
# 미래에는 에이전트 AI가 우리 삶의 자연스러운 일부가 되어, 마치 신뢰하는 동료나 조수처럼 우리와 협력하게 될 것입니다. 이러한 미래를 향해 나아가며, 우리는 기술의 잠재력을 최대한 활용하면서도 인간의 자율성과 가치를 보존하는 방식으로 에이전트 AI를 개발하고 활용해야 합니다.
#
# 에이전트 AI의 세계는 이제 막 펼쳐지기 시작했습니다. 이 여정에 함께 하시겠습니까?
#
# ---
#
# # 소셜 미디어 포스트용 요약
#
# 📱 **[에이전트 AI: 당신의 디지털 슈퍼 파워]**
#
# 인공지능이 단순한 도구에서 지능형 동반자로 진화하고 있습니다! 에이전트 AI는 단순 명령 수행을 넘어 스스로 환경을 인식하고, 복잡한 문제를 해결하며, 사용자를 대신해 행동할 수 있습니다.
#
# 🔹 이메일 분류부터 창의적 콘텐츠 제작까지
# 🔹 개인 비서처럼 당신의 일상을 관리
# 🔹 여러 에이전트가 협력하는 지능형 생태계
#
# 상상해보세요: 아침에 일어나면 AI가 이미 당신의 이메일을 정리하고, 일정을 최적화하고, 오늘의 중요 작업을 준비해둔 세상을!
#
# 미래는 이미 여기 있습니다. 에이전트 AI와 함께할 준비 되셨나요? 🚀
#
# #에이전트AI #인공지능혁명 #디지털동반자 #미래기술
#
# 지금 전체 블로그 포스트 읽기 👉 [링크]
#
# 이 포스트가 도움이 되셨나요? 다른 작업이 필요하시면 알려주세요!

# %%
# 최종 결과 접근
print(f"상태: {result.status}")
# Out:
# 상태: Status.COMPLETED

# %% [markdown]
# 이 예시에서:
#
# * research_agent가 에이전트 AI에 대한 정보를 수집하는 것으로 시작할 수 있습니다
# * creative_agent에게 넘겨주어 매력적인 콘텐츠와 구조를 개발합니다
# * critical_agent가 정확성과 완전성을 위해 콘텐츠를 검토합니다
# * 마지막으로 summarizer_agent가 모든 기여를 응집력 있는 블로그 포스트로 종합합니다
# * 에이전트는 필요에 따라 여러 번 넘겨줄 수 있으며, 스웜이 자동으로 조정을 관리합니다

# %%
# 어떤 에이전트가 참여했는지 확인
for node in result.node_history:
    print(f"에이전트: {node.node_id}")

# 특정 노드에서 결과 가져오기
research_result = result.results["research_agent"].result
print(f"연구: {research_result}")

# 성능 메트릭 가져오기
print(f"총 반복 수: {result.execution_count}")
print(f"실행 시간: {result.execution_time}ms")
print(f"토큰 사용량: {result.accumulated_usage}")
# Out:
# 에이전트: research_agent
# 에이전트: creative_agent
# 연구:
# 총 반복 수: 2
# 실행 시간: 84657ms
# 토큰 사용량: {'inputTokens': 3334, 'outputTokens': 4012, 'totalTokens': 7346}

# %% [markdown]
# 스웜 시스템은 에이전트 조정, 공유 컨텍스트, 넘겨주기 메커니즘을 자동으로 관리합니다. 에이전트는 다른 전문가에게 제어를 이전할 때를 자율적으로 결정할 수 있어, 타임아웃 보호 및 반복적 넘겨주기 감지와 같은 내장 안전 기능을 가진 원활한 협업 워크플로우를 만듭니다.

# %% [markdown]
# ## 스웜을 사용해야 하는 경우:
#
# - 다양한 전문 지식과 전문화된 지식이 필요한 복잡한 작업의 경우
# - 여러 관점과 협업적 문제 해결이 필요한 경우
# - 자율적 에이전트 조정과 집단 지능의 이점을 얻는 작업의 경우
# - 텍스트와 이미지를 함께 처리하는 멀티모달 입력을 다룰 때
# - 에이전트 능력에 기반한 동적 작업 분배가 필요한 프로젝트의 경우
#
# ## 모범 사례
#
# 1. **전문화된 에이전트 생성**: 스웜의 각 에이전트에 대해 명확한 역할 정의
# 2. **서술적 에이전트 이름 사용**: 이름은 에이전트의 전문 분야를 반영해야 함
# 3. **적절한 타임아웃 설정**: 작업 복잡성과 예상 실행 시간에 따라 조정
# 4. **반복적 넘겨주기 감지 활성화**: 핑퐁 동작을 방지하기 위해 `repetitive_handoff_detection_window`와 `repetitive_handoff_min_unique_agents`에 적절한 값 설정
# 5. **다양한 전문 지식 포함**: 스웜에 상호 보완적인 기술을 가진 에이전트가 있는지 확인
# 6. **에이전트 설명 제공**: 다른 에이전트가 그들의 능력을 이해할 수 있도록 에이전트에 설명 추가
# 7. **멀티모달 입력 활용**: 이미지를 포함한 풍부한 입력을 위해 ContentBlocks 사용
#
# ## 결론
#
# 멀티 에이전트 스웜은 창발적 집단 지능을 통해 복잡한 문제를 해결합니다. Strands Agents SDK는 자율적으로 협업하는 맞춤형 에이전트 팀을 생성하기 위한 유연한 스웜 도구와 네이티브 Swarm 클래스를 모두 제공합니다. 개별 모델 제공자, 도구, 구성을 가진 전문화된 에이전트에 작업을 분배함으로써, 스웜은 혼자 작업하는 단일 에이전트보다 더 나은 결과를 달성합니다. 내장 조정 도구, 공유 컨텍스트, 포괄적인 안전 메커니즘을 통해 개발자는 자기 조직화 협업을 통해 복잡하고 다면적인 문제를 처리하는 정교한 멀티 에이전트 시스템을 만들 수 있습니다.
#
# 스웜에 대한 자세한 내용은 [Strands 문서](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/multi-agent/swarm/)를 확인하세요
